# %% [markdown]
# #### readme
# ##### Admin ID = admin
# ##### Admin Password= 1234

# %%
import re

class Food_Ordering_App:
    
    
    
    "Food Ordering App"
    def __init__(self):
        self.FoodId=3
        self.order_no=0
        self.main_menu()
        
    
    
    
    
    def main_menu(self)  :

        self.user_details={}
        self.products={1: {'FoodId': 1, 'food_name': 'Tandoori Chicken', 'quantity': '4 pieces', 'price': 'INR 240', 'disscount': 'No Disscount', 'stock': ''},2: {'FoodId': 2, 'food_name': 'Vegan Burger', 'quantity': '1 Piece', 'price': 'INR 320', 'disscount': 'No Disscount', 'stock': ''},3: {'FoodId': 3, 'food_name': 'Truffle Cake', 'quantity': '500gm', 'price': 'INR 900', 'disscount': 'No Disscount', 'stock': ''}}
        self.product=[]
        self.admin_id="admin"
        self.admin_password="1234"
        
        
        
        self.order_history={}
        
        self.orders={}
        n=True
        while n:
            try:
                print("--------Main Menu-------\n\n")
                print("1)Admin Login \n2)User Login \n3)Exit \n\n")
                print("\n")

                y=int(input("Enter Your Choice"))
                if y==1:
                    self.admin_menu()
                elif y==2:
                    self.user_menu()

                elif y==3:
                    break
                    
            except:
                print("Wrong input")
        
        
        
        
    def admin_menu(self):
        
        while True:
            
            try:
                h=int(input("1)Login \n2)Return to main menu\n\n"))
                
                if h==1:
                    self.admin_login()
                    
                elif h==2:
                    break
                    self.main_menu()
                    
            except:
                print("Wrong input")
                    
                
        
        
        
        
        
        
    def admin_login(self):
        print("------Log-in-----")
        
        Log_in_id=input("Enter Log-in Id")
        
        print("\n")
        
        if Log_in_id==self.admin_id:
            
            
            ad_pass=input("Enter Password")
            
            if ad_pass==self.admin_password:
                print("You Have Successfully Logged in")
        
                

                while True:
                    try:

                        i=int(input("1)Add new food item \n2)Edit Food item using Food Id \n3)View the list of all food items \n4)Remove a food item from the menu using FoodID \n5)Return To Main Menu\n\n"))

                        if i==1:
                            self.Add_new_fooditem()


                        elif i==2:
                            self.edit_Food_item()

                        elif i==3:
                            self.view_all_food_items()

                        elif i==4:
                            self.remove_food_item()

                        elif i==5:
                            
                            self.main_menu()


                        else:
                            break
                            print("Wrong input")

                    except:
                        print("Wrong output")
                else:
                    print("Wrong password")
            else:
                print("Wrong username")

    def Add_new_fooditem(self):
        try:
            self.FoodId+=1
            print("Your New food id is :",self.FoodId)

            self.food_name=input('Enter name of new food item :')
            self.quantity=input("Enter Quantity of food in ml/kg/g/pieces etc. :")
            self.price=input("Enter price of new food item in Rupees :")
            self.disscount=input("Enter disccout on that food in percentage :")
            self.stock=input("Amount left in stock in the restaurant (quatity in numbers):")

            f={}
            f["FoodId"]=self.FoodId
            f["food_name"]=self.food_name
            f["quantity"]=self.quantity
            f["price"]=self.price
            f["disscount"]=self.disscount
            f["stock"]=self.stock
            self.products[self.FoodId]=f
            print("\n\n New Food item Added succesfully")
        except:
            ("Wrong Input")
        
    def view_all_food_items(self):
        for i in range(1,self.FoodId+1):
            values=self.products[i].values()
            valu_list=list(values)
            print(valu_list)
            print("\n")
        
    def remove_food_item(self):
        for i in range(1,self.FoodId+1):
                values=self.products[i].values()
                valu_list=list(values)
                print(valu_list)
                print("\n")
        j=int(input("Enter FoodId of Food that u want to remove"))
        if j in self.products:
            
            self.products.pop(j)
            for i in range(1,self.FoodId+1):
                values=self.products[i].values()
                valu_list=list(values)
                print(valu_list)
                print("\n")
        else:
            print("Sorry FoodId not found")

    def edit_Food_item(self):
        print("\n")
        v=int(input("The the FoodId of food that You want to edit\n"))
        if v in self.products:
            print('Please select one option that you want to update')
            print("\n1)Food name \n2)Quantity of Food \n3)Price \n4)Disscount on food \n5)Stock of Food \n6)Exit\n")
            m=int(input("Enter Your Choice"))
            if m==1:
                self.products[v]["food_name"]=input("Enter New Food Name")
                print("Food name updated Successfully")

            elif m==2:
                self.products[v]["quantity"]=input("Enter New Food Quantity ")
                print("Food Quantity updated Successfully")

            elif m==3:
                self.products[v]['Price']=input("Enter New Food price")
                print("Food price updated Successfully")

            elif m==4:
                self.products[v]['disscount']=input("Enter New Food Disscount")
                print("Food Disscount updated Successfully")

            elif m==5:
                self.products[v]['stock']=input("Enter New Stock")
                print("new Stock updated Successfully")

            elif m==6:
                print('')
            print("\n")   
            print("The Updadate Food record")

            print(self.products[v])
            print("\n")
        else:
            print("FoodId is Not present")
            



    
    def user_menu(self):
        print("-------Users Menu-------")
        b=True
        
        while b:
            try:
                print("1)Register \n2)Login \n3)Return to the Main Menu\n\n")
                us_in=int(input("Enter Your input : "))
                print("\n")
                if us_in ==1:
                    self.user_register()

                elif us_in ==2:
                    self.user_login()

                elif us_in==3:
                    break
                    self.main_menu()
                    
            except:
                print("Wrong input")

        
    def user_register(self):
        
        
            self.user_name=input("\n Enter your full name :")
            self.user_phone_number = (input("Enter your 10 digit Mobile Number :"))
            self.Email_id=input("\n Enter your mail-id :")
            self.address=input("\n Enter your address in a single line(ie without using enter key) :")
            self.password=input("Enter your password : ")
            s={}
            s["user_name"]=self.user_name
            s["user_phone_number"]=self.user_phone_number
            s["user_Email_id"]=self.Email_id
            s["user_address"]=self.address
            s["user_password"]=self.password

            self.user_details[self.user_phone_number]=s

            print("\n Your registration process completed sucessfully ")

            print("\n user_details \n\n ",self.user_details)
            print("\n")
        
        
    
    
    def Update_profile(self):
        print("\n") 
        j=(input("Enter Your Phone number"))
        j=str(j)
        
        
        
        if j in self.user_details:


                print('Please select one option that you want to update')
                print("\n1)User name \n2)Phone Number \n3)Email \n4)Address \n5)Password \n\n")
                n=int(input("Enter Your Choice"))


                if n==1:
                    self.user_details[j]["user_name"]=input("Enter New User Name")
                    print("User Name Updated")

                elif n==2:
                    self.user_details[j]["user_phone_number"]=input("Enter New Phone number")
                    print(" Phone Number Updated") 

                elif n==2:
                    self.user_details[j]["user_phone_number"]=input("Enter New Phone number")
                    print(" Phone Number Updated")

                elif n==3:
                    self.user_details[j]["user_Email_id"]=input("Enter New Email")
                    print("Email Updated")

                elif n==4:
                    self.user_details[j]["user_address"]=input("Enter New Address")
                    print("Address Updated")

                elif n==5:
                    self.user_details[j]["user_password"]=input("Enter New password")
                    print("password Updated")

            
                
            

                print(self.user_details)
                print("\n")
                self.after_login()
            
        else:
            
                print('Detail not found')
        
    
    
    
    def user_login(self):        
        num=(input("\n Enter your contact number to loggin : "))
        print("\n")
        num=str(num)
        if num in self.user_details:
            pas=input("\n Enter your password :")
            if self.user_details[num]['user_password']==pas:
                print("\n Logged in sucessfully\n\n")
                self.after_login()
            else:
                print("Wrong Password")
        
        else:
            print("Your Phone number is not registered")
            print("\nPlease register first\n\n")
        
        
    def after_login(self):
                p=int(input("1) Place New Order\n2) Order History\n3)Update Profile \n4)Exit :"))
                print("\n")
                
                while True:
                    if p==1:
                        self.place_new_order()
                    elif p==2:
                        self.Order_history()

                    elif p==3:
                        self.Update_profile()
                        
                    elif p==4:
                        break
                        self.user_login()
                        
         
            
            
          
            
            
            
            
    def place_new_order(self):
        self.order_no+=1
        
        while True:
            try:
                    print("Please select your order from below")
                    print("1. Tandoori Chicken (4 pieces) [INR 240]","\n2. Vegan Burger (1 Piece) [INR 320]","\n3. Truffle Cake (500gm) [INR 900]\n\n")        
                    
                    m={}
                    print('\n')
                    k=input("Enter Your Order numbers u want to order :")
                    print("Your Order Number is genrated!!!!!!\n")
                    print("Please Note!!!!\n Your Order Number is : ",self.order_no)
                    print("\n")


                    for i in k:
                        if i ==("," or ' ' ):
                                    pass

                        elif i =="1":
                            m[i]="Tandoori Chicken (4 pieces) [INR 240]"

                        elif i =="2":
                            m[i]="Vegan Burger (1 Piece) [INR 320]"

                        elif i=="3":
                            m[i]="Truffle Cake (500gm) [INR 900]"

                        else:
                            print("invalid Input")

                    self.orders[self.order_no]=m
                    print("Your order is :\n",self.orders[self.order_no])
                    self.order_no+=1
                    
                    break

            except:
                    print("Wrong input")
        
        self.after_login()
        
        
        
    def Order_history(self):
        print("\n\n")
        z=int(input("Enter Your Order No : "))
        print("Your order is ",self.orders[z].values())
        self.after_login()
        
        
        
        
        

a=Food_Ordering_App()
# Out:
# --------Main Menu-------
#
#
# 1)Admin Login
# 2)User Login
# 3)Exit
#
#
#
#
# Enter Your Choice1
# 1)Login
# 2)Return to main menu
#
# 1
# ------Log-in-----
# Enter Log-in Idadmin
#
#
# Enter Password1234
# You Have Successfully Logged in
# 1)Add new food item
# 2)Edit Food item using Food Id
# 3)View the list of all food items
# 4)Remove a food item from the menu using FoodID
# 5)Return To Main Menu
#
# 5
# --------Main Menu-------
#
#
# 1)Admin Login
# 2)User Login
# 3)Exit
